# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = [5,2,9,4,7]
y = [10, 5, 8, 4, 2]
plt.plot(x,y)
plt.show()

# %%
x = np.random.uniform(0,1,100)
y = np.random.uniform(0,1,100)
plt.scatter(x,y,color = '#d4d4d4')
plt.show()

# %%
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("Sport Watch Data", fontsize=14)
plt.xlabel("Average Pulse", fontsize=12)
plt.ylabel("Calorie Burnage", fontsize=12)
plt.show()

# %%
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("Sport Watch Data", fontsize=14)
plt.xlabel("Average Pulse", fontsize=12)
plt.ylabel("Calorie Burnage", fontsize=12)
plt.grid()
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sales")

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Shopping")

plt.suptitle("Store Data 2026")
plt.tight_layout()
plt.show()

# %%
x = np.array(["A","B","C","D","E","F"])
y = np.array([3,8,1,10, 4, 5])
plt.bar(x,y)
plt.show()

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
y = np.array([35,25,25,15])
plt.pie(y)
plt.show()

# %%
y = np.array([35,25,25,15])
my_labels = ["Apples","Bananas","Cherries","Dates"]
plt.pie(y,labels=my_labels)
plt.show()

# %%
y = np.array([35,25,25,15, 40, 28, 30])
x = ["Apples","Bananas","Cherries","Dates","Mango","Pineapple", "Cucumber"]
plt.bar(x,y)
plt.show()

# %%
y = np.array([35,25,25,15])
x = ["Apples","Bananas","Cherries","Dates"]
plt.hist(y,x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 y = np.array([35,25,25,15])
# ----> 2 x = np.array["Apples","Bananas","Cherries","Dates"]
#       3 plt.hist(y,x)
#       4 plt.show()
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
y = np.array([35,25,25,15, 40, 28, 30])
x = ["Apples","Bananas","Cherries","Dates","Mango","Pineapple", "Cucumber"]
plt.bar(x,y)
# plt.grid()
plt.show()

# %%
y = np.array([35,25,25,15, 40, 28, 30])
my_labels = ["Apples","Bananas","Cherries","Dates","Mango","Pineapple", "Cucumber"]
plt.pie(y,labels=my_labels)
plt.show()

# %%
y = np.array([35,25,25,15, 40, 28, 30])
my_labels = ["Apples","Bananas","Cherries","Dates","Mango","Pineapple", "Cucumber"]
# plt.pie(y,labels=my_labels)
myexplode = [0,0,0,0,0.2,0,0]
plt.pie(y,labels=my_labels, explode=myexplode)
plt.legend(title="Fruit")
plt.show()

# %%
dataset_1 = np.random.normal(100, 10,200)
dataset_2 = np.random.normal(80, 30, 200)
dataset_3 = np.random.normal(90, 20, 200)
data_to_plot = [dataset_1, dataset_2, dataset_3]
plt.boxplot(data_to_plot)
plt.xticks([1,2,3], ['GroupA', 'GroupB', 'GroupC'])
plt.title("comparison of multiple Groups")
plt.xlabel("Category")
plt.ylabel("Measurement")
p..g(g())
plt.show()
