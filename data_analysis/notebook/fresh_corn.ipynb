# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import duckdb as duckdb
from IPython.display import display

# %%
df = pd.read_csv("/home/adamson/Downloads/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe().T
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# ...

# %% [raw]
# 1. How does price vary with square footage?

# %% [raw]
# 2. What is the price per square foot across neighborhoods?

# %% [raw]
# 3. Does the number of bedrooms significantly affect price?

# %% [raw]
# 4. How does house age impact price?

# %% [raw]
# 5. Which neighborhood has the highest price per square foot?

# %% [raw]
# 6. What is the correlation between features and price?

# %% [raw]
# 7. Do newer houses cost more than older ones?

# %% [raw]
# 8. What is the average price grouped by bedrooms and bathrooms?

# %% [raw]
# 9. How does price vary across decade of construction?

# %% [raw]
# 10. What combination of features yields the highest average price?

# %% [raw]
# 11. Are urban homes consistently more expensive than suburban ones?

# %% [raw]
# 12. How does bathroom count influence price compared to bedrooms?

# %% [raw]
# 13. What is the variance of prices per neighborhood?

# %% [raw]
# 14. What are outliers in house prices?

# %% [raw]
# 15. How does square footage distribution differ by neighborhood?

# %% [raw]
# 16. What is the trend between year built and square footage?

# %% [raw]
# 17. Which feature is the strongest predictor of price?

# %% [raw]
# 18. How does price differ between houses with similar size but different locations?

# %% [raw]
# 19. What is the average age of houses per neighborhood?

# %% [raw]
# 20. Is there diminishing return on price as square footage increases?
